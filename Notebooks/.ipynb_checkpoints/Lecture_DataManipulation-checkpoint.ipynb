# %% [markdown]
# # Data manipulation
# In this lecture you will learn how to work with different types of larger data structures, saving and loading them, reading from .txt and .dat files, what to use when values are missing, and finally how to copy these larger data structures to a new variable.
#
# Do not forget, run the code for your self and see what happens with the data in the tutorial sections!

# %% [markdown]
# ## Tuples
# Similar to an array, tuple is also an ordered set of elements. Tuples work in almost the same way as arrays but there are following important differences between them:
#
# - An array is represented by square brackets whereas a tuple is represented by parentheses and commas.
#
# - Tuples are immutable

# %%
tupl=(5,10,15,20,25,30)

z = ("sdf", 'c', 6.3, 1, Inf)
# Out:
# ("sdf", 'c', 6.3, 1, Inf)

# %% [markdown]
# Accessing the elements works similar to vectors:

# %%
tupl[3:end]
# Out:
# (15, 20, 25, 30)

# %% [markdown]
# #### **E1**
# Try changing a element of the tuple named *tupl*.

# %% [markdown]
# #### **E2**
# Find out how to obtain the 4th element of the second tuple in the tuple *z* below:

# %%
#Tuples of tuples
z = ((1, 3, 4), ('a', 5.7, 9, "This one"))
# Out:
# ((1, 3, 4), ('a', 5.7, 9, "This one"))

# %%
z[2][4]
# Out:
# "This one"

# %% [markdown]
# ### Named tuples
# Additionally, it is possible to assign a name (i.e., key) to each element in a tuple. Creating a key-value pairs. There are three ways to create named tuples:
# - Providing keys and values in separate tuples
# - Providing keys and values in a single tuple
# - Combining two existing named tuples
#
# #### Key and values in separate tuples

# %%
#create 2 tuples
# tuple with names
names_shape = (:corner1, :corner2)
# tuple with values
values_shape = ((100, 100), (200, 200))

#create the named tuple
shape_item2 = NamedTuple{names_shape}(values_shape)
# Out:
# (corner1 = (100, 100), corner2 = (200, 200))

# %% [markdown]
# This allows for an alternative way of indexing by using the key names. To do so, the variable name is followed by a . and then the name of the key. For example:

# %%
# shows the number linked to the key corner1
shape_item2.corner1


shape_item2.corner2 == shape_item2[2]

#shape_item2["corner2"]
# Out:
# true

# %% [markdown]
# #### Key and value in a single tuple
# This is achieved by defining the key-value pair in a single tuple with the = sign in between.

# %%
shape_item = (corner1 = (1, 1), corner2 = (-1, -1), center = (0, 0))
# Out:
# (corner1 = (1, 1), corner2 = (-1, -1), center = (0, 0))

# %% [markdown]
# #### Combining named tuples
# Tuples with unique key names can be merged using the merge function. Do be aware that when there are duplicates of keyword, by default the function only keeps one entry.

# %%
colors_shape = (top = "red", bottom = "green")
shape_item = (corner1 = (1, 1), corner2 = (-1, -1), center = (0, 0))
merge(shape_item, colors_shape)
# Out:
# (corner1 = (1, 1), corner2 = (-1, -1), center = (0, 0), top = "red", bottom = "green")

# %% [markdown]
# #### **E3**
# Create a named tuple containing the RGB codes for the primary colors. RGB stands for red green blue and the maximum value is 255, for example, red would be equal to 255,0,0.

# %% [markdown]
# Finally, there is one alternative way of obtaining all values of a tuple and placing them in separate variables. And can be done as followed:

# %%
shape_item = (corner1 = (1, 1), corner2 = (-1, -1), center = (0, 0))

c1, c2, middle = shape_item

println(middle)
# Out:
# (0, 0)

# %% [markdown]
# This might see like trivial knowledge that is not commonly used, but this is basically what happened with every function that returns multiple variables. An example is the xxx function.

# %%
v = [0,1232,8,64,12,123]

# assigns the outputs as a single tuple named tpl
tpl = findmax(v)
# assigns the outputs to multiple variables
max_val, index = findmax(v)
# Out:
# (1232, 2)

# %% [markdown]
# #### **E4**
# Create a tuple that contains the first four letters of the alphabet (these letters should be of type String). Then unpack this tuple into four variables a, b, c and d.

# %% [markdown]
# More information on tuples can be found here: https://juliateachingctu.github.io/Julia-for-Optimization-and-Learning/stable/lecture_02/tuples/.

# %% [markdown]
# ## Dataframes
# DataFrames are a great data type to use when dealing with tables of data, especially ones that contain different types (e.g., Floats, Strings, ect.). The only requirement is that each column of data has the same number of elements. To load and create DataFrames, we will always need the DataFrames package. Here is a simple example to setup a DataFrame from scratch.

# %%
using ACS
df = DataFrame(a = [1,2], var2 = ["blue", "red"])
# Out:
# Precompiling packages...
#    3193.1 ms  ✓ IOCapture
#    4571.6 ms  ✓ MuladdMacro
#    6377.4 ms  ✓ AbstractFFTs
#    6928.2 ms  ✓ SentinelArrays
#    6916.8 ms  ✓ ExprTools
#    7717.8 ms  ✓ LaTeXStrings
#    8568.0 ms  ✓ IteratorInterfaceExtensions
#    9757.7 ms  ✓ TensorCore
#   10593.2 ms  ✓ WorkerUtilities
#    9488.0 ms  ✓ StatsAPI
#    8574.5 ms  ✓ Contour
#    8654.0 ms  ✓ ConcurrentUtilities
#    8438.9 ms  ✓ ANSIColoredPrinters
#   11555.3 ms  ✓ OffsetArrays
#    9817.2 ms  ✓ IntegerMathUtils
#   12090.3 ms  ✓ Format
#   11887.4 ms  ✓ FillArrays
#   10238.6 ms  ✓ Measures
#    9315.5 ms  ✓ CompilerSupportLibraries_jll
#   11449.4 ms  ✓ Grisu
#   11360.9 ms  ✓ TZJData
#   14103.7 ms  ✓ MacroTools
#    9781.9 ms  ✓ Compat
#   11427.5 ms  ✓ MbedTLS
#   10917.7 ms  ✓ OrderedCollections
#   10912.0 ms  ✓ Observables
#   11267.6 ms  ✓ Requires
#   11268.5 ms  ✓ DataValueInterfaces
#    7907.3 ms  ✓ StableRNGs
#    8771.5 ms  ✓ Unzip
#    8533.6 ms  ✓ Reexport
#    7638.7 ms  ✓ DocStringExtensions
#    7829.7 ms  ✓ MPIPreferences
#    8134.2 ms  ✓ InlineStrings
#    8149.0 ms  ✓ AbstractTrees
#    8723.2 ms  ✓ URIs
#   10115.1 ms  ✓ IrrationalConstants
#    8285.7 ms  ✓ SimpleBufferStream
#    8504.9 ms  ✓ ExceptionUnwrapping
#    8797.9 ms  ✓ PtrArrays
#    9141.1 ms  ✓ TranscodingStreams
#    8663.8 ms  ✓ NaNMath
#   10514.5 ms  ✓ UnicodeFun
#    8925.3 ms  ✓ DelimitedFiles
#    8805.3 ms  ✓ LazilyInitializedFields
#    9040.7 ms  ✓ InvertedIndices
#    9431.7 ms  ✓ DataAPI
#    9263.5 ms  ✓ BitFlags
#    7997.4 ms  ✓ Scratch
#   11159.5 ms  ✓ Crayons
#   10055.1 ms  ✓ LoggingExtras
#   10799.0 ms  ✓ StaticArraysCore
#   11473.2 ms  ✓ SuiteSparse
#   10822.7 ms  ✓ Statistics
#   10522.3 ms  ✓ WoodburyMatrices
#    9851.1 ms  ✓ OpenSSL_jll
#   13218.1 ms  ✓ RecipesBase
#   10709.4 ms  ✓ Graphite2_jll
#    9306.0 ms  ✓ Libmount_jll
#   13888.5 ms  ✓ StringManipulation
#    9614.6 ms  ✓ EpollShim_jll
#    9134.0 ms  ✓ LLVMOpenMP_jll
#    8669.1 ms  ✓ Bzip2_jll
#    9197.1 ms  ✓ Lz4_jll
#    6845.8 ms  ✓ Xorg_libpciaccess_jll
#    7339.0 ms  ✓ libaec_jll
#    7505.1 ms  ✓ Rmath_jll
#    7150.0 ms  ✓ Xorg_libICE_jll
#    7177.4 ms  ✓ Xorg_libXau_jll
#    7913.4 ms  ✓ libpng_jll
#    7587.1 ms  ✓ libfdk_aac_jll
#    7721.1 ms  ✓ LAME_jll
#    7246.7 ms  ✓ LERC_jll
#    7507.2 ms  ✓ fzf_jll
#    7457.0 ms  ✓ JpegTurbo_jll
#    7538.6 ms  ✓ XZ_jll
#    7568.4 ms  ✓ Ogg_jll
#    7361.4 ms  ✓ mtdev_jll
#    7190.0 ms  ✓ Xorg_libXdmcp_jll
#    7485.3 ms  ✓ x265_jll
#    7484.8 ms  ✓ x264_jll
#    7574.4 ms  ✓ libaom_jll
#    7582.4 ms  ✓ Zstd_jll
#    7577.0 ms  ✓ Expat_jll
#    7555.1 ms  ✓ LZO_jll
#    7723.8 ms  ✓ Opus_jll
#    7718.7 ms  ✓ MicrosoftMPI_jll
#    7784.1 ms  ✓ Xorg_xtrans_jll
#    7532.5 ms  ✓ libevdev_jll
#     Primes Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Primes/TX3XQ_Kzo3C.ji.pidfile)
#    7690.8 ms  ✓ Libiconv_jll
#     FillArraysSparseArraysExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/FillArraysSparseArraysExt/pkjPP_Kzo3C.ji.pidfile)
#    7627.1 ms  ✓ Libffi_jll
#     Arpack_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Arpack_jll/m4kdm_Kzo3C.ji.pidfile)
#    7448.2 ms  ✓ eudev_jll
#     OpenSpecFun_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/OpenSpecFun_jll/TDl1L_Kzo3C.ji.pidfile)
#    7444.7 ms  ✓ Git_LFS_jll
#     Showoff Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Showoff/vyYkR_Kzo3C.ji.pidfile)
#    7320.5 ms  ✓ Libuuid_jll
#     PyCall Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/PyCall/GkzkC_Kzo3C.ji.pidfile)
#    7440.4 ms  ✓ FriBidi_jll
#     CompatLinearAlgebraExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/CompatLinearAlgebraExt/Zxpzq_Kzo3C.ji.pidfile)
#    7733.2 ms  ✓ TableTraits
#     DataStructures Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/DataStructures/xKiwJ_Kzo3C.ji.pidfile)
#    9910.6 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#     Ratios Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Ratios/zQEsd_Kzo3C.ji.pidfile)
#    6679.7 ms  ✓ Showoff
#     Adapt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Adapt/rUIgN_Kzo3C.ji.pidfile)
#   12942.5 ms  ✓ Primes
#     FileIO Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/FileIO/6iKRU_Kzo3C.ji.pidfile)
#    5656.7 ms  ✓ Ratios
#     MPItrampoline_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/MPItrampoline_jll/FwcC8_Kzo3C.ji.pidfile)
#   13202.2 ms  ✓ FillArrays → FillArraysSparseArraysExt
#     ParsersExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/ParsersExt/cULGY_Kzo3C.ji.pidfile)
#   12640.8 ms  ✓ OpenSpecFun_jll
#   13297.4 ms  ✓ Arpack_jll
#     MarkdownAST Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/MarkdownAST/6YkiC_Kzo3C.ji.pidfile)
#     LogExpFunctions Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/LogExpFunctions/cmCYR_Kzo3C.ji.pidfile)
#    6224.1 ms  ✓ Adapt
#     AliasTables Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/AliasTables/C6bK3_Kzo3C.ji.pidfile)
#   12143.8 ms  ✓ Compat → CompatLinearAlgebraExt
#     CodecZlib Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/CodecZlib/1TI30_Kzo3C.ji.pidfile)
#   15917.8 ms  ✓ DataStructures
#     RegistryInstances Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/RegistryInstances/58GIZ_Kzo3C.ji.pidfile)
#   12690.3 ms  ✓ MPItrampoline_jll
#   14184.4 ms  ✓ InlineStrings → ParsersExt
#   14588.5 ms  ✓ MarkdownAST
#   16399.2 ms  ✓ AliasTables
#   20695.9 ms  ✓ FileIO
#   16883.4 ms  ✓ CodecZlib
#   18196.1 ms  ✓ RegistryInstances
#   27674.8 ms  ✓ LogExpFunctions
#   20187.8 ms  ✓ Missings
#   22270.5 ms  ✓ PooledArrays
#   20107.0 ms  ✓ RelocatableFolders
#   47263.1 ms  ✓ PyCall
#   19742.5 ms  ✓ StructUtils → StructUtilsStaticArraysCoreExt
#   20046.3 ms  ✓ PDMats
#   10472.1 ms  ✓ ScikitLearnBase
#   11857.1 ms  ✓ AxisAlgorithms
#   21276.1 ms  ✓ Distances
#   24159.3 ms  ✓ FixedPointNumbers
#   16480.6 ms  ✓ FillArrays → FillArraysStatisticsExt
#    8490.6 ms  ✓ libdrm_jll
#   40055.1 ms  ✓ StaticArrays
#    8710.3 ms  ✓ Xorg_libSM_jll
#   21550.2 ms  ✓ Pixman_jll
#   25809.4 ms  ✓ OpenSSH_jll
#   27824.3 ms  ✓ OpenSSL
#   15643.5 ms  ✓ JLFzf
#    7256.1 ms  ✓ Xorg_libxcb_jll
#   22816.8 ms  ✓ FreeType2_jll
#   20563.9 ms  ✓ Rmath
#    6397.9 ms  ✓ Dbus_jll
#    5949.3 ms  ✓ Wayland_jll
#   16966.7 ms  ✓ libvorbis_jll
#     FFTA Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/FFTA/V4Q1C_Kzo3C.ji.pidfile)
#    5102.1 ms  ✓ libinput_jll
#     Arpack Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Arpack/X5VZL_Kzo3C.ji.pidfile)
#   24784.1 ms  ✓ Ghostscript_jll
#     AdaptSparseArraysExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/AdaptSparseArraysExt/7qfxl_Kzo3C.ji.pidfile)
#    5619.3 ms  ✓ Tables
#     OffsetArraysAdaptExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/OffsetArraysAdaptExt/evlsb_Kzo3C.ji.pidfile)
#   19064.3 ms  ✓ Git_jll
#   20035.8 ms  ✓ XML2_jll
#   19979.5 ms  ✓ GettextRuntime_jll
#    7629.3 ms  ✓ Adapt → AdaptSparseArraysExt
#     SortingAlgorithms Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/SortingAlgorithms/6dCmw_Kzo3C.ji.pidfile)
#   27311.1 ms  ✓ Blosc_jll
#    9022.3 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#     WeakRefStrings Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/WeakRefStrings/muGbw_Kzo3C.ji.pidfile)
#   15655.9 ms  ✓ Arpack
#     SpecialFunctions Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/SpecialFunctions/78gOt_Kzo3C.ji.pidfile)
#    9630.4 ms  ✓ FilePathsBase
#   25462.5 ms  ✓ FFTA
#     FillArraysPDMatsExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/FillArraysPDMatsExt/ss8Ey_Kzo3C.ji.pidfile)
#   15075.4 ms  ✓ SortingAlgorithms
#   19387.1 ms  ✓ ChainRulesCore
#   17768.5 ms  ✓ QuadGK
#   43786.7 ms  ✓ Libtiff_jll
#   16411.7 ms  ✓ WeakRefStrings
#   22299.2 ms  ✓ Mocking
#   17517.2 ms  ✓ CategoricalArrays
#   16856.8 ms  ✓ FillArrays → FillArraysPDMatsExt
#   13930.9 ms  ✓ Distances → DistancesSparseArraysExt
#   17053.4 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#   17577.3 ms  ✓ ColorTypes
#   12438.1 ms  ✓ Adapt → AdaptStaticArraysExt
#   17343.4 ms  ✓ FillArrays → FillArraysStaticArraysExt
#   19066.4 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#     TableOperations Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/TableOperations/5GGWt_Kzo3C.ji.pidfile)
#    1378.6 ms  ✓ TableOperations
#     PrettyTables Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/PrettyTables/kRdcL_Kzo3C.ji.pidfile)
#   25211.6 ms  ✓ DecisionTree
#     Git Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Git/2pn0k_Kzo3C.ji.pidfile)
#   36622.3 ms  ✓ SpecialFunctions
#     Hwloc_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Hwloc_jll/tooZ5_Kzo3C.ji.pidfile)
#    9799.3 ms  ✓ Xorg_xcb_util_jll
#     Glib_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Glib_jll/S5dsb_Kzo3C.ji.pidfile)
#    7744.7 ms  ✓ Xorg_libX11_jll
#     Blosc Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Blosc/UZMg8_Kzo3C.ji.pidfile)
#    7007.9 ms  ✓ StructUtils → StructUtilsTablesExt
#     FilePathsBaseMmapExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/FilePathsBaseMmapExt/bw4lJ_Kzo3C.ji.pidfile)
#    9582.5 ms  ✓ FilePathsBase → FilePathsBaseMmapExt
#     FilePathsBaseTestExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/FilePathsBaseTestExt/5f6TB_Kzo3C.ji.pidfile)
#   17003.2 ms  ✓ Hwloc_jll
#     StatsBase Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/StatsBase/EZjIG_Kzo3C.ji.pidfile)
#   16754.3 ms  ✓ Blosc
#     ChainRulesCoreSparseArraysExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/ChainRulesCoreSparseArraysExt/QNMPN_Kzo3C.ji.pidfile)
#   26058.5 ms  ✓ Fontconfig_jll
#   22805.0 ms  ✓ Git
#     LogExpFunctionsChainRulesCoreExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/LogExpFunctionsChainRulesCoreExt/1yuhV_Kzo3C.ji.pidfile)
#   14605.8 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#     DistancesChainRulesCoreExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/DistancesChainRulesCoreExt/xg1UR_Kzo3C.ji.pidfile)
#   32765.6 ms  ✓ Latexify
#   11818.2 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   14503.5 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#     CategoricalArraysJSONExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/CategoricalArraysJSONExt/948k1_Kzo3C.ji.pidfile)
#   13763.5 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#     CategoricalArraysRecipesBaseExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/CategoricalArraysRecipesBaseExt/NgX3N_Kzo3C.ji.pidfile)
#   37015.4 ms  ✓ Glib_jll
#     CategoricalArraysSentinelArraysExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/CategoricalArraysSentinelArraysExt/PVjZ6_Kzo3C.ji.pidfile)
#    8436.4 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   24951.1 ms  ✓ StatsBase
#     Colors Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Colors/NKjaT_Kzo3C.ji.pidfile)
#   17862.4 ms  ✓ Distances → DistancesChainRulesCoreExt
#     NearestNeighbors Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/NearestNeighbors/Yj1kF_Kzo3C.ji.pidfile)
#   10076.0 ms  ✓ CategoricalArrays → CategoricalArraysSentinelArraysExt
#     SpecialFunctionsChainRulesCoreExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/SpecialFunctionsChainRulesCoreExt/wr3Ok_Kzo3C.ji.pidfile)
#   14580.0 ms  ✓ CategoricalArrays → CategoricalArraysJSONExt
#     HypergeometricFunctions Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/HypergeometricFunctions/tHlAh_Kzo3C.ji.pidfile)
#   19722.0 ms  ✓ CategoricalArrays → CategoricalArraysRecipesBaseExt
#     Xorg_xcb_util_image_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_xcb_util_image_jll/dYB7z_Kzo3C.ji.pidfile)
#   10125.2 ms  ✓ Xorg_xcb_util_image_jll
#     Xorg_xcb_util_keysyms_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_xcb_util_keysyms_jll/J2ZCX_Kzo3C.ji.pidfile)
#   23705.8 ms  ✓ HypergeometricFunctions
#     Xorg_xcb_util_renderutil_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_xcb_util_renderutil_jll/3elYg_Kzo3C.ji.pidfile)
#    6631.6 ms  ✓ Xorg_xcb_util_keysyms_jll
#     Xorg_xcb_util_wm_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_xcb_util_wm_jll/WgWW8_Kzo3C.ji.pidfile)
#   38029.4 ms  ✓ ColorVectorSpace
#   36232.4 ms  ✓ Colors
#     Xorg_libXext_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_libXext_jll/H6ltV_Kzo3C.ji.pidfile)
#    8341.5 ms  ✓ Xorg_xcb_util_renderutil_jll
#     Xorg_libXfixes_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_libXfixes_jll/dilDp_Kzo3C.ji.pidfile)
#    9798.2 ms  ✓ Xorg_xcb_util_wm_jll
#     Xorg_libxkbfile_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_libxkbfile_jll/PAhQT_Kzo3C.ji.pidfile)
#   34434.7 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#     CSV Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/CSV/HHBkp_Kzo3C.ji.pidfile)
#    8017.9 ms  ✓ Xorg_libXrender_jll
#   51707.4 ms  ✓ TimeZones
#    7159.0 ms  ✓ Xorg_libXext_jll
#     Documenter Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Documenter/sHGjf_Kzo3C.ji.pidfile)
#    7411.9 ms  ✓ Xorg_libXfixes_jll
#     SparseArraysExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/SparseArraysExt/h5qXK_Kzo3C.ji.pidfile)
#    7225.5 ms  ✓ Xorg_libxkbfile_jll
#     Interpolations Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Interpolations/VpKVx_Kzo3C.ji.pidfile)
#   46177.5 ms  ✓ NearestNeighbors
#     StatsBaseExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/StatsBaseExt/6AXAK_Kzo3C.ji.pidfile)
#    8725.4 ms  ✓ OpenMPI_jll
#  104877.1 ms  ✓ PrettyTables
#     StatsFuns Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/StatsFuns/530lR_Kzo3C.ji.pidfile)
#   18283.5 ms  ✓ Latexify → SparseArraysExt
#     SpecialFunctionsExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/SpecialFunctionsExt/SsZkK_Kzo3C.ji.pidfile)
#   24843.2 ms  ✓ MPICH_jll
#   18124.7 ms  ✓ PDMats → StatsBaseExt
#   17417.9 ms  ✓ CategoricalArrays → CategoricalArraysStatsBaseExt
#     ColorSchemes Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/ColorSchemes/EO5fj_Kzo3C.ji.pidfile)
#  128579.2 ms  ✓ HTTP
#   11111.5 ms  ✓ Xorg_xcb_util_cursor_jll
#   17978.0 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#     Xorg_libXrandr_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_libXrandr_jll/UlKyO_Kzo3C.ji.pidfile)
#   18589.2 ms  ✓ Widgets
#    8655.9 ms  ✓ Xorg_libXinerama_jll
#   28384.0 ms  ✓ StatsFuns
#     Xorg_libXcursor_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_libXcursor_jll/iyuAX_Kzo3C.ji.pidfile)
#    9106.4 ms  ✓ Xorg_libXrandr_jll
#     Xorg_libXi_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_libXi_jll/1sAS5_Kzo3C.ji.pidfile)
#   15658.8 ms  ✓ TimeZones → TimeZonesRecipesBaseExt
#    8564.8 ms  ✓ Libglvnd_jll
#    6675.6 ms  ✓ Xorg_libXcursor_jll
#     Clustering Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Clustering/Ovl2Q_Kzo3C.ji.pidfile)
#   28976.4 ms  ✓ ColorSchemes
#     DataFrames Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/DataFrames/AR9oZ_Kzo3C.ji.pidfile)
#    6685.1 ms  ✓ Xorg_libXi_jll
#     HDF5_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/HDF5_jll/w9xrx_Kzo3C.ji.pidfile)
#   50548.7 ms  ✓ Interpolations
#     HTTPExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/HTTPExt/VIoHu_Kzo3C.ji.pidfile)
#    8425.7 ms  ✓ libva_jll
#    8448.5 ms  ✓ Xorg_xkbcomp_jll
#   20198.7 ms  ✓ Clustering
#     PlotUtils Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/PlotUtils/YveHG_Kzo3C.ji.pidfile)
#   77227.7 ms  ✓ CSV
#     Xorg_xkeyboard_config_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Xorg_xkeyboard_config_jll/Os86B_Kzo3C.ji.pidfile)
#   25611.5 ms  ✓ FileIO → HTTPExt
#   28042.3 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   14783.4 ms  ✓ Xorg_xkeyboard_config_jll
#     xkbcommon_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/xkbcommon_jll/1mf1R_Kzo3C.ji.pidfile)
#    7005.8 ms  ✓ xkbcommon_jll
#     Vulkan_Loader_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Vulkan_Loader_jll/MvdhX_Kzo3C.ji.pidfile)
#    7112.5 ms  ✓ Vulkan_Loader_jll
#     Qt6Base_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Qt6Base_jll/Lg7vK_Kzo3C.ji.pidfile)
#   56322.7 ms  ✓ HDF5_jll
#     HDF5 Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/HDF5/L7Dga_Kzo3C.ji.pidfile)
#   52993.3 ms  ✓ Distributions
#   53339.6 ms  ✓ PlotUtils
#     PlotThemes Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/PlotThemes/QxsMm_Kzo3C.ji.pidfile)
#   16231.2 ms  ✓ Distributions → DistributionsTestExt
#   84463.2 ms  ✓ Cairo_jll
#   23139.0 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#   25577.9 ms  ✓ MultivariateStats
#  153230.9 ms  ✓ Documenter
#   31088.3 ms  ✓ PlotThemes
#   35170.4 ms  ✓ RecipesPipeline
#   55539.0 ms  ✓ HDF5
#     H5Zblosc Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/H5Zblosc/635PC_Kzo3C.ji.pidfile)
#   38442.1 ms  ✓ HarfBuzz_jll
#   35187.1 ms  ✓ KernelDensity
#   74718.1 ms  ✓ Qt6Base_jll
#     Qt6Svg_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Qt6Svg_jll/gmRiM_Kzo3C.ji.pidfile)
#     Qt6ShaderTools_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Qt6ShaderTools_jll/O8E7A_Kzo3C.ji.pidfile)
#   12561.7 ms  ✓ H5Zblosc
#     JLD Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/JLD/l8ijy_Kzo3C.ji.pidfile)
#   14126.6 ms  ✓ JLD
#   26895.7 ms  ✓ libass_jll
#   27078.4 ms  ✓ Pango_jll
#    5514.2 ms  ✓ libdecor_jll
#    5267.5 ms  ✓ GLFW_jll
#  160374.9 ms  ✓ DataFrames
#     RData Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/RData/idMMA_Kzo3C.ji.pidfile)
#     DataFramesExt Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/DataFramesExt/8XGBh_Kzo3C.ji.pidfile)
#   44264.0 ms  ✓ Qt6ShaderTools_jll
#   44319.5 ms  ✓ Qt6Svg_jll
#     Qt6Declarative_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Qt6Declarative_jll/rB4FL_Kzo3C.ji.pidfile)
#    8307.2 ms  ✓ Latexify → DataFramesExt
#   13335.0 ms  ✓ RData
#     RDatasets Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/RDatasets/JyIbx_Kzo3C.ji.pidfile)
#    9228.2 ms  ✓ RDatasets
#   42509.5 ms  ✓ FFMPEG_jll
#   15227.5 ms  ✓ Qt6Declarative_jll
#     Qt6Wayland_jll Being precompiled by another process (pid: 67954, pidfile: /Users/saersamanipour/.julia/compiled/v1.10/Qt6Wayland_jll/mzY2s_Kzo3C.ji.pidfile)
#    3251.3 ms  ✓ Qt6Wayland_jll
#    8093.6 ms  ✓ FFMPEG
#   12155.2 ms  ✓ GR_jll
#    7607.4 ms  ✓ GR
#    3415.6 ms  ✓ GR → IJuliaExt
#  110793.1 ms  ✓ Plots
#    8487.9 ms  ✓ Plots → FileIOExt
#    9422.1 ms  ✓ Plots → IJuliaExt
#   17903.7 ms  ✓ StatsPlots
#   24508.0 ms  ✓ ACS
#   267 dependencies successfully precompiled in 733 seconds. 21 already precompiled.
# 2×2 DataFrame
#  Row │ a      var2
#      │ Int64  String
# ─────┼───────────────
#    1 │     1  blue
#    2 │     2  red

# %% [markdown]
# Here you can see that each named column is filled with a vector containing the same number of elements. Accessing values in a DataFrame can be done in two ways: 1) similar to matrices and 2) as a combination of the names tuples and indexing vectors. The following lines of code also obtain the same element.

# %%
# 1 Matrix like
df[2,2]                 #get the element on the second row in the second column

# 2 Named tuple + vector like
df[2,"var2"]            #get the second element in from the column names var2
df[!,"var2"][2]         #first set of brackets extract the column -> get the 2nd element
df[:,"var2"][2]         #same as previous
df.var2[2]              #same as previous
# Out:
# "red"

# %% [markdown]
# #### **E5**
# Using the following DataFrame df2,
#
# a) Obtain all column names of df2. Check the function names().
#
# b) Get the 6th value from the last column.
#
# c) Find all the rows that have a sepal length > 5.
#
# d) Replace the 4th value in the first column with "NA". What to you think is the issue here?
#
# e) Create a DataFrame from scratch that contains different types of variables in a column. What is the difference with d)?

# %%
#load a DataFrame from RDatasets

df2 = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼─────────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa
#    6 │         5.4         3.9          1.7         0.4  setosa
#    7 │         4.6         3.4          1.4         0.3  setosa
#    8 │         5.0         3.4          1.5         0.2  setosa
#    9 │         4.4         2.9          1.4         0.2  setosa
#   10 │         4.9         3.1          1.5         0.1  setosa
#   11 │         5.4         3.7          1.5         0.2  setosa
#   ⋮  │      ⋮           ⋮            ⋮           ⋮           ⋮
#  141 │         6.7         3.1          5.6         2.4  virginica
#  142 │         6.9         3.1          5.1         2.3  virginica
#  143 │         5.8         2.7          5.1         1.9  virginica
#  144 │         6.8         3.2          5.9         2.3  virginica
#  145 │         6.7         3.3          5.7         2.5  virginica
#  146 │         6.7         3.0          5.2         2.3  virginica
#  147 │         6.3         2.5          5.0         1.9  virginica
#  148 │         6.5         3.0          5.2         2.0  virginica
#  149 │         6.2         3.4          5.4         2.3  virginica
#  150 │         5.9         3.0          5.1         1.8  virginica
#                                                    129 rows omitted

# %% [markdown]
# Now we could also add more data to the df2. To add new columns, you can simply type a new name into the DataFrame and assign the values belonging to it. Remember, the values should be a vector with a number of elements equal to the number of rows.

# %%
df2[!,"MyNewColumn"] = 1:size(df2,1)
# Out:
# 1:150

# %% [markdown]
# Additionally, it is also possible to add new rows/entries to a DataFrame. For adding individual rows, push!() is the function that you would want to use. This appends a tuple of the values of the new row to the selected DataFrame. In the case of adding multiple entries/a DataFrame to a DataFrame, append!() can be used.
#
# Notice the !, this is used in julia with functions when you are adding something to an existing variable or something else.

# %%
# adding a single entry
push!(df2, (1, 2, 3, 4, "x",1))

# This appends df2 to df2, meaning that all entries will be in there which after running this line
append!(df2, df2)
# Out:
# 302×6 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species    MyNewColumn
#      │ Float64      Float64     Float64      Float64     Cat…       Int64
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa               1
#    2 │         4.9         3.0          1.4         0.2  setosa               2
#    3 │         4.7         3.2          1.3         0.2  setosa               3
#    4 │         4.6         3.1          1.5         0.2  setosa               4
#    5 │         5.0         3.6          1.4         0.2  setosa               5
#    6 │         5.4         3.9          1.7         0.4  setosa               6
#    7 │         4.6         3.4          1.4         0.3  setosa               7
#    8 │         5.0         3.4          1.5         0.2  setosa               8
#    9 │         4.4         2.9          1.4         0.2  setosa               9
#   10 │         4.9         3.1          1.5         0.1  setosa              10
#   11 │         5.4         3.7          1.5         0.2  setosa              11
#   ⋮  │      ⋮           ⋮            ⋮           ⋮           ⋮           ⋮
#  293 │         6.9         3.1          5.1         2.3  virginica          142
#  294 │         5.8         2.7          5.1         1.9  virginica          143
#  295 │         6.8         3.2          5.9         2.3  virginica          144
#  296 │         6.7         3.3          5.7         2.5  virginica          145
#  297 │         6.7         3.0          5.2         2.3  virginica          146
#  298 │         6.3         2.5          5.0         1.9  virginica          147
#  299 │         6.5         3.0          5.2         2.0  virginica          148
#  300 │         6.2         3.4          5.4         2.3  virginica          149
#  301 │         5.9         3.0          5.1         1.8  virginica          150
#  302 │         1.0         2.0          3.0         4.0  x                    1
#                                                                 281 rows omitted

# %% [markdown]
# #### **E6**
# Using the following DataFrame df3,
#
# a) Add a new column named *new1* containing only ones to df3.
#
# b) Add a new entry/row to df3 with values c1 = 4, c2 = "B", and new1 = 2.
#
# c) Find out how to add a column after c2 and before new1, containing the values [4,3,2,1].
#
# d) Copy and insert the 4th row on the 3rd row position to the matrix.

# %%
df3 = DataFrame(c1 = [1,2,3], c2 = ["A", "A", "C"])
# Out:
# 3×2 DataFrame
#  Row │ c1     c2
#      │ Int64  String
# ─────┼───────────────
#    1 │     1  A
#    2 │     2  A
#    3 │     3  C

# %% [markdown]
# For even more information on DataFrames see: https://dataframes.juliadata.org/stable/man/getting_started/.

# %% [markdown]
# ## Dictionaries
# Dictionaries are similar to DataFrames in the sense that they also contain a collection of data that can be saved under different names. However, dictionaries do not have a table layout like DataFrames, meaning that each named variable in a dictionary can have different number of elements, contain a matrix, just a single string, or even a DataFrame or Dictionary.
#
# How to setup a dictionary:

# %%
dict1 = Dict("A" => 1, "B" => [2,4,8])

#or with symbols (i.e., :Name)

dict1 = Dict(:A => 1, :B => [2,4,8])
# Out:
# Dict{Symbol, Any} with 2 entries:
#   :A => 1
#   :B => [2, 4, 8]

# %% [markdown]
# To access the values in dictionaries, you have to use the keywords to access each field. Here "A" was defined first, however, it does not have the index of 1, which it would have had if it was a tuple. This is because dictionaries are a collection of unordered data.

# %%
#obtain everything in A
dict1["A"]

#obtain everything in B
dict1["B"]

#obtain the 2nd element in B
dict1["B"][2]
# Out:
# KeyError: key "A" not found
#
# Stacktrace:
#  [1] getindex(h::Dict{Symbol, Any}, key::String)
#    @ Base ./dict.jl:498
#  [2] top-level scope
#    @ In[112]:2

# %% [markdown]
# Two code blocks back, you see the alternative of using a symbol (:FollowedByName) instead of strings. When this is used l["A"] does not work and l[:A] does. This is because "A" == :A is false. So depending if you use symbols or strings, you will also have to use those for indexing. This also means that you can create Dictionaries with a mix of keyword types.

# %%
dict2 = Dict("a" => 1, "b" => 2, "c" => "Hello", 1 => 10)
# Out:
# Dict{Any, Any} with 4 entries:
#   "c" => "Hello"
#   "b" => 2
#   "a" => 1
#   1   => 10

# %% [markdown]
# Here, you can see that even a number can be used as a keyword in dictionaries. Now:

# %%
dict2[1]   #returns 10
# Out:
# 10

# %% [markdown]
# #### **E7**
# What does dict2[2] return and why?

# %% [markdown]
# Dictionaries in Julia allow accessing all the keys and all the values at once. This can be done with the use of pre-defined keywords keys and values.

# %%
Keys = keys(dict2)
Values = values(dict2)
# Out:
# ValueIterator for a Dict{Any, Any} with 4 entries. Values:
#   "Hello"
#   2
#   1
#   10

# %% [markdown]
# Values in a key-value pair can be changed and additionally keys can be easily added by using:

# %%
#adding new key-value pairs
dict2["d"] = "New variable"

#replace existing ones
dict2["c"] = [1,2,3]

# or add values within a field
append!(dict2["c"],[4,5,6])
println(dict2)
# Out:
# Dict{Any, Any}("c" => [1, 2, 3, 4, 5, 6], "b" => 2, "a" => 1, 1 => 10, "d" => "New variable")

# %% [markdown]
# #### **E8**
# Create a dictionary that uses the following strings as keys and assign a value to each key that is equal to the number of chars in each string.

# %%
strs = ["One", "Two", "Three", "Four", "Five"]
# Out:
# 5-element Vector{String}:
#  "One"
#  "Two"
#  "Three"
#  "Four"
#  "Five"

# %% [markdown]
# #### **E9**
# Convert DataFrame df2 from exercise 4 to a dictionary.
#
# #### **E10**
# Convert the following dictionary to a DataFrame, where the dictionary keys are ordered in alphabetical order in the DataFrame (i.e., The first column is "A").

# %%
using ACS.StatsBase

rDict = Dict(i => rand(1:100, 10) for i in sample(["A", "B", "C", "D", "Ee", "F", "G", "h"],5, replace = false))
# Out:
# WARNING: using StatsBase.var in module Main conflicts with an existing identifier.
# WARNING: using StatsBase.middle in module Main conflicts with an existing identifier.
# Dict{String, Vector{Int64}} with 5 entries:
#   "B" => [26, 29, 90, 34, 61, 27, 57, 18, 25, 57]
#   "A" => [37, 14, 38, 89, 100, 71, 13, 5, 96, 20]
#   "G" => [71, 30, 99, 76, 4, 10, 89, 2, 36, 21]
#   "h" => [13, 50, 92, 27, 32, 25, 68, 41, 93, 42]
#   "F" => [82, 63, 79, 39, 26, 54, 90, 27, 46, 58]

# %% [markdown]
# # Files
# So far we have created small data collections that are easy and quick to make. However, this is not representative for the data we generally work with, coming form measurements. For these datasets it is a lot easier if we can directly load it from a file. For this, we first need the path to this file and then we will go into the ways to load files with different extensions.
#
# ## Paths
# A path to a file is of type string and consists of the path/folder names on how to get to that file. For example the current working directory that Julia is in right now can be found with the following function and is a prefect example of a path:

# %%
pwd()
# Out:
# "/Users/saersamanipour"

# %% [markdown]
# Running this line of code will show you a path that starts with the disk name and then is followed by multiple folder names. These names are divided by either "\\\\" or "/", depending on whether you are working on windows or linux/macOS. This is what Julia works with by default depending on the operating system, but they work interchangeably. For example:

# %%
"c:\\folder/folder\\folder"
# Out:
# "c:\\folder/folder\\folder"

# %% [markdown]
# These two examples above show paths leading to folders, but what if we need to access a specific file in that folder? We can either just type the full path to that file:

# %%
"c:\\folder/folder\\folder\\file_name.csv"
# Out:
# "c:\\folder/folder\\folder\\file_name.csv"

# %% [markdown]
# Or if they are save in different variables, it is good practice to use the joinpath function. This unction automatically ensures that the separation sings between the path and file name is corrected.

# %%
path = "c:\\folder/folder\\folder"    
file = "file_name.csv"
full_path = joinpath(path, file)
# Out:
# "c:\\folder/folder\\folder/file_name.csv"

# %% [markdown]
# ## Loading and Saving
# Now that we can make a path, we can actually save our data in the desired folder with the name that we want to give it.
#
# ### Values and arrays
# Sometimes you might just want to save a simple value, tuple, vector, or matrix to a file without needed to convert it, for example,to a DataFrame or Dictionary. For this we can use the BSON package and save the variables without an extension (e.g., without .csv).

# %%
using ACS.BSON

var_name = zeros(5,4)
BSON.@save("Example\\path\\name_to_save_the_variable_as", var_name)

# and we can load this variable later on using 
BSON.@load("Example\\path\\name_to_save_the_variable_as", var_name)
# Out:
# UndefVarError: `BSON` not defined

# %% [markdown]
# Notice that when loading a variable back we again use var_name as second input. This is the key name it got assigned to and only through this name you can load the values saved in the file. This also means that you are able to store multiple variables in a single file. Try the following with the String temp_var being a valid path on your laptop:

# %%
using DataSci4Chem.BSON

var_name = zeros(5,4)
other_var = "Something"

BSON.@save("temp_var", var_name, other_var)

#NOW: Stop the REPL and Start it again to open a new session that has not seen the variables var_name and other_var

#Try:
BSON.@load("temp_var", var1)
#What goes wrong?

#you can load only a single variable back from that file
BSON.@load("temp_var", other_var)
println(var_name)
println(other_var)

#Or load multiple varibales back at once
BSON.@load("temp_var", other_var, var_name)     #notice that the order does not matter
println(var_name)
println(other_var)
# Out:
# ArgumentError: Package DataSci4Chem not found in current path.
# - Run `import Pkg; Pkg.add("DataSci4Chem")` to install the DataSci4Chem package.
#
# Stacktrace:
#  [1] macro expansion
#    @ ./loading.jl:1846 [inlined]
#  [2] macro expansion
#    @ ./lock.jl:270 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1827
#  [4] #invoke_in_world#3
#    @ ./essentials.jl:926 [inlined]
#  [5] invoke_in_world
#    @ ./essentials.jl:923 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1820

# %% [markdown]
# ### CSV
# To read a csv file into a DataFrame we first need the packages CSV and DataFrames.

# %%
## CSV file

var = CSV.read("Example\\path\\file.csv", DataFrame)

CSV.write("Example\\path\\file.csv", var)
# Out:
# ArgumentError: "Example\path\file.csv" is not a valid file or doesn't exist
#
# Stacktrace:
#  [1]
#    @ CSV ~/.julia/packages/CSV/LiiJM/src/context.jl:314
#  [2] #File#32
#    @ ~/.julia/packages/CSV/LiiJM/src/file.jl:222 [inlined]
#  [3] CSV.File(source::String)
#    @ CSV ~/.julia/packages/CSV/LiiJM/src/file.jl:162
#  [4] read(source::String, sink::Type; copycols::Bool, kwargs::@Kwargs{})
#    @ CSV ~/.julia/packages/CSV/LiiJM/src/CSV.jl:117
#  [5] read(source::String, sink::Type)
#    @ CSV ~/.julia/packages/CSV/LiiJM/src/CSV.jl:113
#  [6] top-level scope
#    @ In[125]:3
# Some type information was truncated. Use `show(err)` to see complete types.

# %% [markdown]
# ### XLSX
# XLSX is used for reading and writing excel spread sheets. These files can contain multiple "pages" in excel, which makes it a bit more complex to work with. It is either possible to load in the full xlsx file with all worksheets or load a specific sheet into a DataFrame. For a more extensive tutorial on how to work with the first option see: https://felipenoris.github.io/XLSX.jl/stable/tutorial/. This page also contains more information on how to  write excel file, but for now our main focus is to be able to read an excel file into a DataFrame.

# %%
using ACS.XLSX

#loading a spread sheet
xf = XLSX.readxlsx("myfile.xlsx")   #this will also show the sheet names and data ranges in the REPL
#assessing a worksheet
sh = xf["mySheet"]

#loading a single worksheet into a dataframe
df = DataFrame(XLSX.readtable("myfile.xlsx", "mysheet"))
# Out:
# UndefVarError: `XLSX` not defined

# %% [markdown]
# ### JLD
# JLD stands for Julia dictionary and is the file type as which dictionaries can be saved. For example:

# %%
using ACS.JLD
using ACS.HDF5

d = Dict(
    ("a", "b") => [1, 2, 3],
    ("c", "d") => [4, 5, 6],
    ("e", "f") => [7, 8, 9]
)

JLD.save("path\\data.jld", "name", d)
JLD.load("path\\data.jld")["name"]
# Out:
# Dict{Tuple{String, String}, Vector{Int64}} with 3 entries:
#   ("c", "d") => [4, 5, 6]
#   ("e", "f") => [7, 8, 9]
#   ("a", "b") => [1, 2, 3]

# %% [markdown]
# #### **E11**
# Save and load the variables generated in exercise E3, E5, and E9 with their appropriate method.

# %% [markdown]
# # .TXT and .DAT files
# Finally, we will be discussing .txt and .dat files that can be ready and manipulated through the IOstream. These are files that file types that are often generated, either containing the measured data of the instrument or extra information that is recorded in a separate file (e.g., instrument settings). First lets create a text file through Julia.

# %%
#open a new file
f1 = open("New Text Document.txt", "w")

#write a string to it
write(f1, "Hello world!")

#Finally, DO NOT FORGET to close the file
close(f1)

#Now load this file into another variable and see what it contains
o = open("New Text Document.txt", "r")
read(o,String)

close(o)

# %% [markdown]
# There are different ways to open files as shown above. The example above first uses "w" that stands for write, meaning that the file is opened and we can write information into it. Then in the second instance "r" is used, which means we can only read what is in the file and not write information to it. The table below shows an overview of the different options to open files.
#
# |Mode|	Description	Keywords|
# |----|-----------|
# |r	|read|
# |w	|write, create, truncate|
# |a	|write, create, append|
# |r+	|read, write|
# |w+	|read, write, create, truncate|
# |a+	|read, write, create, append|

# %% [markdown]
# So far the text file contained a single line of information. Although this is generally not the case. Lets first create a multiline file and practice working with that. To do so run the following:

# %%
#open a new file
f1 = open("New Text Document.txt", "w")

#write a string to it
for lines = rand(1:20,5)
    write(f1, "Hello world $lines"*"!\n")        #\n in a string start a new line
end

#Finally, DO NOT FORGET to close the file
close(f)
# Out:
# invalid redefinition of constant Main.f
#
# Stacktrace:
#  [1] top-level scope
#    @ In[129]:2

# %% [markdown]
# Running write multiple times before closing the file will append each string after the other and we used the \n to ensure that the new writes start on a new line.
#
# #### **E12**
# a) Open the above created text file in read mode.
#
# b) Now you can read the lines of the contents with the function readlines().
#
# c) For each line, extract the number and save them in a vector.

# %% [markdown]
# For more info on the iostream see: https://docs.julialang.org/en/v1/base/io-network/

# %% [markdown]
# # Copying data structures
# Finally, when copying/assigning larger data structures as a whole to a new variable, it might be that the new variable just points to the old one. When this happens it would mean that changing a value in the new variable also happens for the old variable. For example:

# %%
old_var = DataFrame(y = [1,2],x = [2,3])
new_var = old_var

#change a value in new_var
new_var[1,1] = 2
#now the value has changed in both variables
println(new_var[1,1])
println(old_var[1,1])
println(new_var[1,1] == old_var[1,1])
# Out:
# 2
# 2
# true

# %% [markdown]
# To avoid this we can use the deepcopy function. This creates a deep copy and everything is copied recursively, resulting in a fully independent object.

# %%
old_var = DataFrame(y = [1,2],x = [2,3])
new_var = deepcopy(old_var)                 #!!!!!!!!!!!!

#change a value in new_var
new_var[1,1] = 2
#now the value has changed in both variables
println(new_var[1,1])
println(old_var[1,1])
println(new_var[1,1] == old_var[1,1])
# Out:
# 2
# 1
# false

# %% [markdown]
# # More exercises
#
# #### **E13**
# Get the file "MSBNK-AAFC-AC000003.txt" from canvas. This contains the information of a single mass spectrum from MassBank EU.
#
# a) Loop through the lines in this file and find on which line the date is saved. How would you find this information if the line number on which this information is not recorded would not be consistent.
#
# b) Write a function that returns all the m/z values and the intensities of the peaks recorded in the .txt file of the molecule. Assume that line numbers likely change between different MS spectra, meaning that you need a dynamic way for extracting the peaks.
#
#
# #### **E14**
# Get the file "MassBankDatabase_p1.csv" from canvas. This file contains a fraction of all the spectra recorded on MassBank EU, for which the information was obtained in a similar manner as the previous exercise.
#
# a) Obtain all entries of the compound with the InChIKey OQIQSTLJSLGHID-WNWIJWBNSA-N.
#
# b) Next filter those entries based on their precursor type. Only keep the protonated spectra (i.e., [M+H]+).
#
# c) Obtain the fragments (MZ_VALUES) for each spectrum and plot these. Is there a trend between the fragments obtained for each spectrum and the collision energy?
